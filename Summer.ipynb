# %% [markdown]
# # Summer Olympics Data Analysis Assignment

# %%
import pandas as pd

# %% [markdown]
# ### 1. In how many cities Summer Olympics is held so far?

# %%
df=pd.read_csv('summer.csv')
print(len(df['City'].unique()))
# Out:
# 22

# %% [markdown]
# ### 2. Which sport is having most number of Gold Medals so far? (Top 5)

# %%
c=df[df['Medal']=='Gold']
p=[]
for i in c['Sport'].unique():
    p.append([i,len(c[c['Sport']==i])])
p=pd.DataFrame(p,columns=['sport','freq'])
p=p.sort_values(by="freq",ascending=False)
p=p.head()
print(p)
p.plot(x='sport',y='freq',kind='bar')
# Out:
#          sport  freq
# 0     Aquatics  1421
# 1    Athletics  1215
# 17      Rowing   890
# 4   Gymnastics   820
# 3      Fencing   552

# %% [markdown]
# ### 3. Which sport is having most number of medals so far? (Top 5)

# %%
x=[]
y=df[['Sport','Medal']]
y=y.dropna()
for i in y['Sport'].unique():
    x.append([i,len(y[y['Sport']==i])])
x=pd.DataFrame(x,columns=['sport','freq'])
x=x.sort_values(by="freq",ascending=False)
x=x.head()
print(x)
x.plot(x='sport',y='freq',kind='bar')
# Out:
#          sport  freq
# 0     Aquatics  4170
# 1    Athletics  3638
# 17      Rowing  2667
# 4   Gymnastics  2307
# 3      Fencing  1613

# %% [markdown]
# ### 4. Which player has won most number of medals? (Top 5)

# %%
z=df[['Athlete','Medal']]
z=z.dropna()
q=[]
for i in z['Athlete'].unique():
    q.append([i,len(z[z['Athlete']==i])])
q=pd.DataFrame(q,columns=['Athlete','freq'])
q=q.sort_values(by="freq",ascending=False)
q=q.head()
print(q)
q.plot(x='Athlete',y='freq',kind='bar')
# Out:
#                     Athlete  freq
# 18640       PHELPS, Michael    22
# 7197       LATYNINA, Larisa    18
# 9948     ANDRIANOV, Nikolay    15
# 6591           ONO, Takashi    13
# 5103   MANGIAROTTI, Edoardo    13

# %% [markdown]
# ### 5. Which player has won most number Gold Medals of medals? (Top 5)

# %%
w=c[c['Medal']=='Gold']
w=w.dropna()
r=[]
for i in w['Athlete'].unique():
    r.append([i,len(w[w['Athlete']==i])])
r=pd.DataFrame(r,columns=['Athlete','freq'])
r=r.sort_values(by="freq",ascending=False)
r=r.head()
print(r)
r.plot(x='Athlete',y='freq',kind='bar')
# Out:
#                Athlete  freq
# 6851   PHELPS, Michael    18
# 4630       LEWIS, Carl     9
# 907       NURMI, Paavo     9
# 2714  LATYNINA, Larisa     9
# 3320       SPITZ, Mark     9

# %% [markdown]
# ### 6. In which year India won first Gold Medal in Summer Olympics?

# %%
u=df[['Year','Country','Medal']]
u=u.dropna()
u=u[u['Medal']=='Gold']
u=u[u['Country']=='IND']
u=u.sort_values(by="Year")
u=u.head(1)
print("year=",u['Year'].values)
# Out:
# year= [1928]

# %% [markdown]
# ### 7. Which event is most popular in terms on number of players? (Top 5)

# %%
v=df[['Athlete','Event']]
v=v.dropna()
o=[]
m=[]
for i in v['Event'].unique():
    n=v[v['Event']==i]
    for j in n['Athlete'].unique():
        o.append([i,j])
o=pd.DataFrame(o,columns=['Event','Athlete'])
for i in o['Event'].unique():
    m.append([i,len(o[o['Event']==i])])
m=pd.DataFrame(m,columns=['Event','freq'])
m=m.sort_values(by="freq",ascending=False)
m=m.head()
print(m)
m.plot(x='Event',y='freq',kind='bar')
# Out:
#                         Event  freq
# 80                   Football  1357
# 176                    Hockey  1154
# 138          Team Competition   975
# 83   Eight With Coxswain (8+)   828
# 327                Basketball   814

# %% [markdown]
# ### 8. Which sport is having most female Gold Medalists? (Top 5)

# %%
t=df[['Sport','Gender','Medal']]
t=t.dropna()
t=t[t['Medal']=='Gold']
t=t[t['Gender']=='Women']
s=[]
for i in t['Sport'].unique():
    s.append([i,len(t[t['Sport']==i])])
s=pd.DataFrame(s,columns=['sport','freq'])
s=s.sort_values(by="freq",ascending=False)
s=s.head()
print(s)
s.plot(x='sport',y='freq',kind='bar')
# Out:
#          sport  freq
# 4     Aquatics   589
# 7    Athletics   389
# 8   Gymnastics   268
# 14      Rowing   217
# 11  Volleyball   166
